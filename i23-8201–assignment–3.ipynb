# %%
from pathlib import Path
from pathml.core import HESlide, SlideDataset

# assuming that all WSIs are in a single directory, all with .svs file extension
data_dir = Path("/path/to/data/")
wsi_paths = list(data_dir.glob("*.svs"))

# create a list of SlideData objects by loading each path
wsi_list = [HESlide(p) for p in wsi_paths]

# initialize a SlideDataset
dataset = SlideDataset(wsi_list)

# %%
# Creating a Pipeline for Pre-Processing
from pathml.preprocessing import Pipeline, BoxBlur, TissueDetectionHE

pipeline = Pipeline([
    BoxBlur(kernel_size=15),
    TissueDetectionHE(mask_name = "tissue", min_region_size=500,
                      threshold=30, outer_contours_only=True)
])

# %% [markdown]
# Strengths of PathML:
#
# Precision in Tissue Subtype Classification:
#  PathML demonstrates high precision in classifying tissue subtypes, leveraging advanced machine learning algorithms. This precision enhances the accuracy of pathology diagnoses, especially in scenarios with complex tissue compositions.
#
# Automated Segmentation for Efficiency:
#  PathML excels in automating the segmentation process, efficiently delineating distinct regions within tissue samples. This automation significantly accelerates the workflow, allowing pathologists to focus on detailed analyses rather than manual segmentation.
#
# Adaptability to Diverse Tissues and Organs:
# The adaptability of PathML to diverse tissue characteristics and organs is a notable strength. The model can learn and generalize from various datasets, ensuring consistent performance across different anatomical structures.
#
# Weaknesses of PathML:
#
# Dependency on Quality and Quantity of Data:
# PathML's performance is contingent on the quality and quantity of training data. In scenarios where annotated datasets are limited or contain biases, the model may struggle to generalize effectively, impacting its accuracy.
#
# Computational Resource Intensity:
# Training complex models like PathML can be computationally intensive, requiring substantial resources. This may pose a challenge for users with limited access to high-performance computing resources.
#
# Interpretability Challenges:
# The interpretability of PathML's decision-making process might be challenging. Deep learning models often operate as "black boxes," making it difficult to explain how specific decisions are reached, which could be a concern in critical medical contexts

# %%
import os
# !pip install openslide-python
# !apt-get install openslide-tools
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# !update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java
# !java -version
# !pip install pathml
# Out:
# Collecting openslide-python
#   Downloading openslide-python-1.3.1.tar.gz (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.0/359.0 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from openslide-python) (9.4.0)
# Building wheels for collected packages: openslide-python
#   Building wheel for openslide-python (setup.py) ... done
#   Created wheel for openslide-python: filename=openslide_python-1.3.1-cp310-cp310-linux_x86_64.whl size=33550 sha256=2a0c5ba9256ecb8e1b6f07434c8055ec4e7b48a11530bedc1e25cab14da97ca5
#   Stored in directory: /root/.cache/pip/wheels/79/79/fa/29a0087493c69dff7fd0b70fab5d6771002a531010161d2d97
# Successfully built openslide-python
# Installing collected packages: openslide-python
# Successfully installed openslide-python-1.3.1
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libopenslide0
# Suggested packages:
#   libtiff-tools
# The following NEW packages will be installed:
#   libopenslide0 openslide-tools
# 0 upgraded, 2 newly installed, 0 to remove and 10 not upgraded.
# Need to get 104 kB of archives.
# After this operation, 297 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenslide0 amd64 3.4.1+dfsg-5build1 [89.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 openslide-tools amd64 3.4.1+dfsg-5build1 [13.8 kB]
# Fetched 104 kB in 1s (197 kB/s)
# Selecting previously unselected package libopenslide0.
# (Reading database ... 120880 files and directories currently installed.)
# Preparing to unpack .../libopenslide0_3.4.1+dfsg-5build1_amd64.deb ...
# Unpacking libopenslide0 (3.4.1+dfsg-5build1) ...
# Selecting previously unselected package openslide-tools.
# Preparing to unpack .../openslide-tools_3.4.1+dfsg-5build1_amd64.deb ...
# Unpacking openslide-tools (3.4.1+dfsg-5build1) ...
# Setting up libopenslide0 (3.4.1+dfsg-5build1) ...
# Setting up openslide-tools (3.4.1+dfsg-5build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java to provide /usr/bin/java (java) in manual mode
# openjdk version "1.8.0_382"
# OpenJDK Runtime Environment (build 1.8.0_382-8u382-ga-1~22.04.1-b05)
# OpenJDK 64-Bit Server VM (build 25.382-b05, mixed mode)
# Collecting pathml
#   Downloading pathml-2.1.1-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from pathml) (23.1.2)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.10/dist-packages (from pathml) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pathml) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pathml) (1.11.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from pathml) (0.19.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from pathml) (0.14.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pathml) (3.7.1)
# Requirement already satisfied: openslide-python in /usr/local/lib/python3.10/dist-packages (from pathml) (1.3.1)
# Collecting pydicom (from pathml)
#   Downloading pydicom-2.4.3-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from pathml) (3.9.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pathml) (1.2.2)
# Requirement already satisfied: dask[distributed] in /usr/local/lib/python3.10/dist-packages (from pathml) (2023.8.1)
# Collecting anndata>=0.7.6 (from pathml)
#   Downloading anndata-0.10.3-py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.2/119.2 kB 11.2 MB/s eta 0:00:00
# Collecting scanpy (from pathml)
#   Downloading scanpy-1.9.6-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 59.4 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pathml) (2.1.0+cu118)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from pathml) (4.8.0.76)
# Collecting python-bioformats>=4.0.0 (from pathml)
#   Downloading python_bioformats-4.0.7-py3-none-any.whl (40.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 MB 11.9 MB/s eta 0:00:00
# Collecting loguru (from pathml)
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.2 MB/s eta 0:00:00
# Collecting array-api-compat (from anndata>=0.7.6->pathml)
#   Downloading array_api_compat-1.4-py3-none-any.whl (29 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anndata>=0.7.6->pathml) (1.1.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from anndata>=0.7.6->pathml) (8.4.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from anndata>=0.7.6->pathml) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pathml) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pathml) (2023.3.post1)
# Collecting boto3>=1.14.23 (from python-bioformats>=4.0.0->pathml)
#   Downloading boto3-1.29.6-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: future>=0.18.2 in /usr/local/lib/python3.10/dist-packages (from python-bioformats>=4.0.0->pathml) (0.18.3)
# Collecting python-javabridge==4.0.3 (from python-bioformats>=4.0.0->pathml)
#   Downloading python-javabridge-4.0.3.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->pathml) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->pathml) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->pathml) (2023.6.0)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->pathml) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->pathml) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->pathml) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->pathml) (6.8.0)
# Requirement already satisfied: distributed==2023.8.1 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->pathml) (2023.8.1)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->pathml) (3.1.2)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->pathml) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->pathml) (1.0.7)
# Requirement already satisfied: psutil>=5.7.2 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->pathml) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->pathml) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->pathml) (3.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->pathml) (6.3.2)
# Requirement already satisfied: urllib3>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->pathml) (2.0.7)
# Requirement already satisfied: zict>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->pathml) (3.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pathml) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pathml) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pathml) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pathml) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pathml) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pathml) (3.1.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy->pathml) (1.3.2)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.10/dist-packages (from scanpy->pathml) (3.2.1)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.10/dist-packages (from scanpy->pathml) (0.58.1)
# Requirement already satisfied: patsy in /usr/local/lib/python3.10/dist-packages (from scanpy->pathml) (0.5.3)
# Requirement already satisfied: seaborn!=0.13.0 in /usr/local/lib/python3.10/dist-packages (from scanpy->pathml) (0.12.2)
# Collecting session-info (from scanpy->pathml)
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from scanpy->pathml) (4.66.1)
# Collecting umap-learn>=0.3.10 (from scanpy->pathml)
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pathml) (3.2.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pathml) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pathml) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pathml) (1.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->pathml) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->pathml) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->pathml) (1.12)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->pathml) (2.1.0)
# Collecting botocore<1.33.0,>=1.32.6 (from boto3>=1.14.23->python-bioformats>=4.0.0->pathml)
#   Downloading botocore-1.32.6-py3-none-any.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 75.2 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.14.23->python-bioformats>=4.0.0->pathml)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.8.0,>=0.7.0 (from boto3>=1.14.23->python-bioformats>=4.0.0->pathml)
#   Downloading s3transfer-0.7.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask[distributed]->pathml) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.10.3->distributed==2023.8.1->dask[distributed]->pathml) (2.1.3)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.41.0->scanpy->pathml) (0.41.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy->scanpy->pathml) (1.16.0)
# Collecting pynndescent>=0.5 (from umap-learn>=0.3.10->scanpy->pathml)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 6.4 MB/s eta 0:00:00
# Collecting stdlib_list (from session-info->scanpy->pathml)
#   Downloading stdlib_list-0.10.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->pathml) (1.3.0)
# Building wheels for collected packages: python-javabridge, umap-learn, session-info
#   Building wheel for python-javabridge (setup.py) ... done
#   Created wheel for python-javabridge: filename=python_javabridge-4.0.3-cp310-cp310-linux_x86_64.whl size=1743089 sha256=9f0ec44a47e92ab240111d5b588396752e52888bd8d884631354a2bb8a974dd4
#   Stored in directory: /root/.cache/pip/wheels/35/58/be/c5d71b71a9dd6585f897fa5b2d021e03962eb30d6b20797396
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86831 sha256=66a48806db93c6b7c66b7d95e712460b475bfe3afd007d271e840956dea9f965
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8026 sha256=42284eb04fcd6423e52a309d86f6e0afdb3d4b588e14433e09f488d1ac1ab814
#   Stored in directory: /root/.cache/pip/wheels/6a/aa/b9/eb5d4031476ec10802795b97ccf937b9bd998d68a9b268765a
# Successfully built python-javabridge umap-learn session-info
# Installing collected packages: stdlib_list, python-javabridge, pydicom, loguru, jmespath, array-api-compat, session-info, botocore, s3transfer, pynndescent, anndata, umap-learn, boto3, scanpy, python-bioformats, pathml
# Successfully installed anndata-0.10.3 array-api-compat-1.4 boto3-1.29.6 botocore-1.32.6 jmespath-1.0.1 loguru-0.7.2 pathml-2.1.1 pydicom-2.4.3 pynndescent-0.5.11 python-bioformats-4.0.7 python-javabridge-4.0.3 s3transfer-0.7.0 scanpy-1.9.6 session-info-1.0.0 stdlib_list-0.10.0 umap-learn-0.5.5
