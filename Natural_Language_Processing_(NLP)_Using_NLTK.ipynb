# %%
  import nltk
  nltk.download('gutenberg')
  import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.corpus import gutenberg

# %%
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# How to acess raw data in corpus

# %%
r_bible = gutenberg.raw('bible-kjv.txt')
r_bible[:100]
# Out:
# '[The King James Bible]\n\nThe Old Testament of the King James Bible\n\nThe First Book of Moses:  Called '

# %%
r_bible = gutenberg.raw('blake-poems.txt')
r_bible[:100]
# Out:
# '[Poems by William Blake 1789]\n\n \nSONGS OF INNOCENCE AND OF EXPERIENCE\nand THE BOOK of THEL\n\n\n SONGS '

# %% [markdown]
# # How to acess specific words in **corpus**

# %%
l_w_bible = gutenberg.words('bible-kjv.txt')
l_w_bible[:10]
# Out:
# ['[', 'The', 'King', 'James', 'Bible', ']', 'The', 'Old', 'Testament', 'of']

# %%
l_w_bible = gutenberg.words('shakespeare-caesar.txt')
l_w_bible[:10]
# Out:
# ['[',
#  'The',
#  'Tragedie',
#  'of',
#  'Julius',
#  'Caesar',
#  'by',
#  'William',
#  'Shakespeare',
#  '1599']

# %% [markdown]
# # How to acess specific sentences in corpus

# %%
l_s_bible = gutenberg.sents('shakespeare-caesar.txt')
l_s_bible
# Out:
# [['[', 'The', 'Tragedie', 'of', 'Julius', 'Caesar', 'by', 'William', 'Shakespeare', '1599', ']'], ['Actus', 'Primus', '.'], ...]

# %% [markdown]
# # Brown corpus

# %%
import nltk
nltk.download('brown')

from nltk.corpus import brown
brown.categories()
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
brown.fileids(categories=['humor'])
# Out:
# ['cr01', 'cr02', 'cr03', 'cr04', 'cr05', 'cr06', 'cr07', 'cr08', 'cr09']

# %% [markdown]
# # Exploring corpuses
# basic structure of **corpora**
# ![Screenshot 2024-04-17 at 2.34.43 AM.png](data:image/png;base64,...)
